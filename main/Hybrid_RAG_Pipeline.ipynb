# %% [markdown]
# # Hybrid RAG Pipeline
#
# Notebook pipeline nằm trong thư mục `main/` theo yêu cầu tổ chức lại code.
#
# Nếu bạn cần chạy nhanh toàn hệ thống, dùng `Run_Project.ipynb` trong cùng thư mục.
